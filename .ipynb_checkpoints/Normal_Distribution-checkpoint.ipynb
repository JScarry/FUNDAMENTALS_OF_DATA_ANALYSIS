# %%
# Readme file about Normal Distribution
## Author: Jarlath Scarry

This readme file and the assosciated files and code make up my submission for the Normal distribution part of the FUNDAMENTALS_OF_DATA-ANALYSIS module

# %% [markdown]
# # Notebook Plan:
#
# 1. Create notebook in repositry and start plan (week1)
#
# 2. Introduction to Normal distribution (week2)
#
# 3. Add some code to give examples of normal distribution (week3)
#
# 4. Discuss the normal distribution curve (week4)
#
# 5. Pick sample data and plot distribution and discuss (Week5+6)
#
# 6. Review notebook, tidy and check referencing (week7)
#
# 7. Examples of where normal didtribution is used and its importance (week8+9)
#
# 8. Revisit summary and begin conclusion     (week10)
#
# 9. Referencing and Review (week11)

# %% [markdown]
# ## WHAT IS NORMAL DISTRIBUTION
#
# Normal distribution is a probability distribution that is symmetric about the mean,
# showing that data near the mean are more frequent in occurrence than data far from the mean.
# It is also known as the Gaussian distribution after the German mathematician Carl Friedrich Gauss who first described the phenomen.
#
# In graphical form, the normal distribution appears as a "bell curve". [4]
# An example is shown below.

# %% [markdown]
# ## Properties of a Normal distribution bell curve
#
# The area under the graph represents 100% of the data
# Empirical rule. Data falls within a certain number of standard deviations from the mean [1] [2]
# 68% =1 (sigma)
# 95% = 2sd
# 99.7% = 3sd
#
# There are a few basic properties of a normal distribution.
# The graph will be Symmetrical
# The Mean, Mode and Median are all equal

# %% [markdown]
# ![Normal_Distribution_image1.PNG](attachment:Normal_Distribution_image1.png)

# %%
The normal distribution is the most common type of distribution assumed in technical 
stock market analysis and in other types of statistical analyses. 

A standard normal distribution has two key parameters: the mean and the standard deviation.

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\JS\\repos\\FUNDAMENTALS_OF_DATA_ANALYSIS'

# %% [markdown]
# ![Bell_Curve_Infograph1.PNG](attachment:Bell_Curve_Infograph1.PNG)

# %% [markdown]
# ###References
#
#
# [1]  https://www.statisticshowto.com/probability-and-statistics/normal-distributions/#whatisND
#
# [2]  https://youtu.be/iMak-EW4HtM
#
# [3]  https://en.wikipedia.org/wiki/Normal_distribution
#
# [4]  https://www.investopedia.com/terms/n/normaldistribution.asp
#
# [5]  https://www.simplypsychology.org/normal-distribution.html
