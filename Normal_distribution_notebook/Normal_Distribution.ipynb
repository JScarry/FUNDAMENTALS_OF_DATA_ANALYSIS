# %% [markdown]
# # Readme file about Normal Distribution
# ## Author: Jarlath Scarry
#
# This Notebook and the assosciated files and code make up my submission for the Normal distribution part of the FUNDAMENTALS_OF_DATA-ANALYSIS module

# %% [markdown]
# ## WHAT IS NORMAL DISTRIBUTION
#
# First we could ask, what is statistical distribution? A statistical distribution or probability distribution describes how values are distributed for a field. In other words, the statistical distribution shows which values are common and uncommon. We use a statistical distribution to determine how likely a particular value is.
#
# [15] (IBM Cognos Analytics, Nov 2022)
#
# "The normal distribution is the single most important distribution in the social sciences"
#
# [16] (Normal Distribution, encyclopedia.com, May 2018)
#
#
# It is important because many psychological and educational variables are distributed normally (approximately). For example if we measures job satisfaction, the of reading ability of a population or memory are some of the many psychological variables approximately normally distributed. Although these distributions are only approximately normal, they are usually very close. A second reason the normal distribution is so important is that it is easy for mathematical statisticians to work with. This means that many kinds of statistical tests can be derived for normal distributions.
#
# It was first observed by Galileo Galilei (1564–1642) when he noticed errors in astronomical observations were not totally random, but instead they had some patterns. In the first decade of the nineteenth century the mathematicians Adrien-Marie Legendre (1752–1833) and the German mathematician Carl Friedrich Gauss (1777–1855) worked out the precise mathematical formula, and Gauss demonstrated that this curve provided a close fit to the empirical distribution of observational errors.
#
# While the normal distribution was first applied to the description of measurement errors, scientists later began to realize that it also described variation in human phenomena independent of errors of measurement. In 1835 Adolphe Quetelet (1796–1874) applied the normal distribution to many physical attributes, such as height. [16] (Normal Distribution, encyclopedia.com, May 2018)
#
# But it was in 1869 Francis Galton (1822–1911) found the normal distribution could be extended to cover individual differences in ability. For this reason intellegence tests score a persons test based on a normal distribution. It is important to remember that while many, not all human attributes or behavioral events are normally distributed, for example data about alcohol or coffee consumption are usually not bell shaped. These typically follow a right-skewed distribution. They will often have a clusters of values (nonconsumers and consumers and heavy consumers). We need to be aware of whether variables follow normal or non-normal distributions as this will influences how we go about analysing and describing the data.[17] (Dealing With Non-normal Data,  Kristin L. Sainani, Dec 2012)
#
# Normal distribution is a probability distribution that is symmetric about the mean, showing that data near the mean are more frequent in occurrence than data far from the mean.
#
# In graphical form, the normal distribution appears as a "bell curve".
# An example is shown below.
#
# [13] (Normal Distribution, Math is fun, Dec 2022)

# %% [markdown]
# ![Bell_curve_standard_normal_distribution.PNG](attachment:Bell_curve_standard_normal_distribution.PNG)

# %% [markdown]
# A good summary then is; The term “Normal Distribution Curve” or “Bell Curve” is used to describe the mathematical
# concept called normal distribution, sometimes referred to as Gaussian distribution.
# It refers to the shape that is created when a line is plotted using the data points
# for an item that meets the criteria of ‘Normal Distribution’. [3] (Normal distribution, Wikipedia, Nov 2022)
#
# The general form of its probability density function is shown below.
# It is written in LaTeX typeset code as discussed in our outliers lectures.

# %% [markdown]
# $$ p(x) = \frac{1}{\sqrt{2 \pi \sigma^2 }} e^{-\frac{(x - \mu)^2}{2 \sigma^2}} $$

# %% [markdown]
# ## Properties of a Normal distribution bell curve
#
# The area under the graph represents 100% of the data
# Empirical rule. Data falls within a certain number of standard deviations from the mean
# 68% =1σ (sigma)
# 95% = 2σ
# 99.7% = 3σ
#
# [1] (Normal Distributions (Bell Curve): Definition, Word Problems, Stephanie Glen, NOv 2022)
# [2] (Normal Distribution Definition and Properties, Prof. Essa, Nov 2015)
#
# There are a few basic properties of a normal distribution.
#
# The graph will be Symmetrical.
#
# The Mean, Mode and Median are all equal.
#
# The standard normal distribution has a mean of 0 and a variance of 1 standard deviation
#
# Image below from Wikipedia [3] (Normal distribution, Wikipedia, Nov 2022)

# %% [markdown]
# ![image info](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Standard_deviation_diagram_micro.svg/375px-Standard_deviation_diagram_micro.svg.png)

# %% [markdown]
# ## The Empirical rule of standard deviation.
#
# In a standard normal distribution:
# 68% of the data will fall within one standard deviation from the mean
# 95% of the data will fall within two standard deviations
# 99.73% of the data points will fall within three standard deviations from the mean
# 99.9937% of the data points will fall within four standard deviations from the mean
# 99.999943% of the data points will fall within five standard deviations from the mean
# 99.9999998% of the data points will fall within six standard (6 Sigma) deviations from the mean

# %% [markdown]
# ## 6 σ
#
# Normal distribution is used in industary whare a high degree of accuracy is required, such as in medical device manufacture. The term 6 sigma or 6σ is commonly used and it refers to a quality control philosophy which has its roots found in normal distribution. Put simply, the aim during manufacture is that the process should operate within 6 sigma at all times. Measurments are taken and during the process and results should show that 99.9999998% of items fall within the specifications.

# %% [markdown]
# ## Central limit theorem
#
# Normal distribution follows the central limit theory which states that various independent factors influence a particular trait. When these all independent factors contribute to a phenomenon, their normalized sum tends to result in a Gaussian distribution.
#
# [8] (9 Real Life Examples Of Normal Distribution, Nov 2022)
# [9] (The Normal Distribution and the Central Limit Theorem, Ruby Nixson, Sept 2021)

# %% [markdown]
# ![Leaving_cert_points1.PNG](attachment:Leaving_cert_points1.PNG)

# %% [markdown]
# ## Standardised exam Results
#
# The example of distribution of examination results is commonly used when discussing distribution curves. The graphs above show the points achieved by leaving cert students in 2018 and 2019. The percentage of students achieving points is on the Y axis while the points achieved are grouped into bands or bins on the X axis (bins of 100 points from 0 to 599 and  and 600+). The two distributions look very similar. This is by design, since Leaving Cert results are standardised from year to year. Usually a sample of papers are corrected and the marking scheme is adjusted to get the desired distribution of results.
# [6] (GRADE INFLATION AND THE 2020 LEAVING CERTIFICATE, Sept 2020)
# [7] (Six Sigma: What is the Normal Distribution Curve?, Bruce Wells, Nov 2022)

# %% [markdown]
# ## Probability density function (PDF)
#
# In probability theory, a probability density function (PDF), or density of a continuous random variable, is a function whose value at any given sample (or point) in the sample space (the set of possible values taken by the random variable) can be interpreted as providing a relative likelihood that the value of the random variable would be equal to that sample.
#
# So the PDF is used to find the probability of the random variable falling within a range of values, rather than being a specific value.
#
# [19] (Probability Density Function, wikipedia, Jan 2023)
#
# Lets consider the probability of a womans height being exactly 1.7m?
#
# Well if we want to find somone exactly 1.700000m it would be very unlikley, infact we could say that probability is close to Zero.
#
# However, what is the probability of finding a woman around 1.7m, say we were willing to accept a height between 1.68 to 1.72m? Then we can calculate the probability based on the area under that part of the bell curve.
#
#
# ![image info](https://plus.maths.org/content/sites/plus.maths.org/files/articles/2021/Prob_dist/normal_height.png)
#
# [20] (The normal distribution, Marianne, 7 Jan 2022)

# %% [markdown]
# ## Normal distribution examples using Python Numpy
#
# The code below uses Numpy to generate random numbers in a normal distribution.
#
# [10] (Normal (Gaussian) Distribution, Dec 2022)
#
# [12] (A Quick Introduction to Numpy Random Normal, Joshua Ebner, June 2022)
#
# 3 parameters in the function. These allow us to control the mean, the standard deviation, and the size of the normal distribution
#
# I ran a random sample of 100 numbers, mean = 0 and standard deviation of 0.1 and plotted the random results. The data appears to be normally distributed but the bell curve is not well defined due to the small sample size. When the sample size is increased to 10000 we can see a well defined bell curve

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

random_data_100 = random.normal(0, 0.1, 100)

random_data_10000 = random.normal(0, 0.1, 10000)
sns.distplot(random_data_100, hist=True, bins=10).set(title='random_data_100')
plt.show()
sns.distplot(random_data_10000, hist=True, bins=100).set(title='random_data_1000')
#print(random_data_sample)
plt.show()
# Out:
# C:\Users\JS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\JS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Sample size
#
#  We see again, that the larger the sample size (100,000 in this case) the more defined the shape of the "Bell curve". The distribution is more "normal"

# %%
import numpy as np

mu, sigma = 0, .1 # mean and standard deviation
s = np.random.default_rng() .normal(mu, sigma, 100000)
#print(s)

import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(s, 100, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ))
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ## Normal distribution for different $\mu$ and $\sigma$
#
# A good explanation of the effect of $\mu$ and $\sigma$ came up in one of our Programming_for_Data_Analysis lectures with Brian McGinley
#
# [11] (Code from Programming_for_Data_Analysis lectures, Brian McGinley, Nov 2022)
#
# The code below plots 4 normal distributions with different values for $\mu$ and $\sigma$.
#
# In the yellow plot for example, a value from our data is very likley to be close to -1 (which is $\mu$, our mean), then in the green plot a value from our data is less likley to be close to our mean, which in this case is 0. Any value picked from our data is likley to fall within 3 times $\mu$, as seen in the green plot where most values are between -9 and +9.
#
# Also, what is maybe more noticable on the green plot here, but is true for all distributions, the X value does drop towards zero as you move away from the mean, but it does not reach zero but continues to infinity. So in the green plot it may be possible to find a value of -50, but this would be very unlikley.

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as ss

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = 14, 10

# %%
x = np.linspace(-10.0, 10.0, 1000)

plt.fill(x, ss.norm.pdf(x, loc= 0.0, scale=1.0), label="$\mu = 0.0, \sigma = 1.0$", c='b', alpha=0.6, lw=3.0)
plt.fill(x, ss.norm.pdf(x, loc= 2.0, scale=1.0), label="$\mu = 2.0, \sigma = 1.0$", c='r', alpha=0.6, lw=3.0)
plt.fill(x, ss.norm.pdf(x, loc= 0.0, scale=3.0), label="$\mu = 0.0, \sigma = 3.0$", c='g', alpha=0.6, lw=3.0)
plt.fill(x, ss.norm.pdf(x, loc= -1.0, scale=0.5), label="$\mu = -1.0, \sigma = .05$", c='y', alpha=0.6, lw=3.0)

plt.title("Normal distribution for different $\mu$ and $\sigma$")
plt.legend();

# %% [markdown]
# ## Is my data normal?
#
# We can check our data to see if it fits the "normal distribution". In this case I took the familiar iris dataset and ran the setosa sepal length values through the "Fitter" library. We can run the best_fit library which checks our data against a library of over 100 different distributions. This takes about 30 mins to run so I changes it to specified 5 common distributions, including normal to see how they compare. In this case, normal distribution returned the second lowest summsquare error after Burr distribution, so yes I would consider normal distribution to be a good description for setosa sepal length
#
# [14] (Finding the Best Distribution that Fits Your Data using Python’s Fitter Library, Rahul Raoniar, Jun 2021)

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import time
from fitter import Fitter

iris_df = sns.load_dataset("iris") #load iris dataset directly from seaborn
print(iris_df.tail()) #display the new iris_df tail 

setosa_df = iris_df.loc[iris_df.loc[:,'species'] == 'setosa'] #select only setosa entries from the species column
print()
print(setosa_df.tail()) #display the new setosa_df tail to check it has been selected correctly - only setosa
print()

sns.set_style('white') #set the plot style
sns.set_context("paper", font_scale = 2) #set the plot style
sns.displot(data=setosa_df, x="sepal_length", kind="hist", bins = 50, aspect = 1.5,) #plot histogram of setosa sepal lengths 

sepal_length_fn = setosa_df["sepal_length"].values #create function for sepal length values
f = Fitter(sepal_length_fn,distributions =['gamma','lognorm',"beta","burr","norm"]) #check for best fit of data [14]
#f.get_best(method = 'sumsquare_error') #removed this as it takes 30mins to run
f.fit()
f.summary() #print a summmary
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#     sepal_length  sepal_width  petal_length  petal_width species
# 45           4.8          3.0           1.4          0.3  setosa
# 46           5.1          3.8           1.6          0.2  setosa
# 47           4.6          3.2           1.4          0.2  setosa
# 48           5.3          3.7           1.5          0.2  setosa
# 49           5.0          3.3           1.4          0.2  setosa
# Fitting 5 distributions: 100%|█████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  3.55it/s]
# ...

# %% [markdown]
# ## Conclusions
#
# So in conclusion we can say Normal Distribution is important in statistics and often they are very naturally occurring. One of the main reasons for its popularity is that it occurs very commonly in most of the things we see in nature around us including psycalogical behavioral events. While they are only approximately normal, they are (with a large enough sample size) quite close.
#
# Also it is relatively easy for mathematical statisticians to work with. The standard deviation and the mean can be easily found. This means many statistical tests can be derived for normal distributions. Difficult statistical calculations can be easily understood with the use of Normal Distribution curves. For a very long time the bell curve has given us meaningful insights into probability distribution.
#
#
# ![image info](https://media.licdn.com/dms/image/C5612AQEz4qxphE7Nbg/article-inline_image-shrink_400_744/0/1601398112815?e=1677715200&v=beta&t=jLebF3O73x2p37Y_-HfqWF5nJNyPQ-vHDr5J21-Xiqo)
#
# [18] (The Powers of “Normal Distribution”, Paras Varshney, Sep 2020)

# %% [markdown]
# ### References
#
# APA - Referencing
#
# [1]  (Normal Distributions (Bell Curve): Definition, Word Problems, Stephanie Glen, NOv 2022) Retrieved from: https://www.statisticshowto.com/probability-and-statistics/normal-distributions/#whatisND
#
# [2]  (Normal Distribution Definition and Properties, Prof. Essa, Nov 2015) Retrieved from: https://youtu.be/iMak-EW4HtM
#
# [3]  (Normal distribution, Wikipedia, Nov 2022) Retreived from: https://en.wikipedia.org/wiki/Normal_distribution
#
# [4]  (Normal Distribution: What It Is, Properties, Uses, and Formula, JAMES CHEN, July 2022) Retreived from: https://www.investopedia.com/terms/n/normaldistribution.asp
#
# [5]  (Introduction to the Normal Distribution (Bell Curve), Dr. Saul McLeod, 2019) Retreived from: https://www.simplypsychology.org/normal-distribution.html
#
# [6]  (GRADE INFLATION AND THE 2020 LEAVING CERTIFICATE, Sept 2020) Retreived from: https://degreesofbelief.roryquinn.com/grade-inflation-and-the-2020-leaving-certificate
#
# [7] (Six Sigma: What is the Normal Distribution Curve?, Bruce Wells, Nov 2022) Retreived from: https://blog.masterofproject.com/normal-distribution-curve/#:~:text=Let%E2%80%99s%20summarize%3A%20The%20normal%20distribution%20curve%20is%20a,either%20side%20Of%20the%20most%20frequently%20occurring%20value
#
# [8]  (9 Real Life Examples Of Normal Distribution, Nov 2022) Retreived from: https://studiousguy.com/real-life-examples-normal-distribution/  # central limit thoerem
#
# [9]  (The Normal Distribution and the Central Limit Theorem, Ruby Nixson, Sept 2021) Retreived from: https://tomrocksmaths.com/2021/09/28/the-normal-distribution-and-the-central-limit-theorem/ # checking phone
#
# [10] (Normal (Gaussian) Distribution, Dec 2022) Retreived from: https://www.w3schools.com/python/numpy/numpy_random_normal.asp # Visualization of Normal Distribution
#
# [11] (Code from Programming_for_Data_Analysis lectures, Brian McGinley, Nov 2022)
#
# [12] (A Quick Introduction to Numpy Random Normal, Joshua Ebner, June 2022) Retreived from: https://www.sharpsightlabs.com/blog/numpy-random-normal/ # A Quick Introduction to Numpy Random Normal
#
# [13] (Normal Distribution, Dec 2022) Retreived from: https://www.mathsisfun.com/data/standard-normal-distribution.html
#
# [14] (Finding the Best Distribution that Fits Your Data using Python’s Fitter Library, Rahul Raoniar, Jun 2021) Retreived from:
# (https://medium.com/the-researchers-guide/finding-the-best-distribution-that-fits-your-data-using-pythons-fitter-library-319a5a0972e9) #check for best fit of data
#
# [15] (IBM Cognos Analytics, Nov 2022) Retrieved from: https://www.ibm.com/docs/en/cognos-analytics/11.1.0?topic=terms-statistical-distribution
#
# [16] (Normal Distribution, encyclopedia.com, May 2018) Retrieved from: https://www.encyclopedia.com/science-and-technology/mathematics/mathematics/normal-distribution#3
#
# [17] (Dealing With Non-normal Data,  Kristin L. Sainani, Dec 2012) Retrieved from: https://onlinelibrary.wiley.com/doi/10.1016/j.pmrj.2012.10.013
#
# [18] (The Powers of “Normal Distribution”, Paras Varshney, Sep 2020) Retrieved from: https://media.licdn.com/dms/image/C5612AQEz4qxphE7Nbg/article-inline_image-shrink_400_744/0/1601398112815?e=1677715200&v=beta&t=jLebF3O73x2p37Y_-HfqWF5nJNyPQ-vHDr5J21-Xiqo
#
# [19] (Probability Density Function, wikipedia, Jan 2023) Retrieved from: https://en.wikipedia.org/wiki/Probability_density_function
#
# [20] (The normal distribution, Marianne, 7 Jan 2022) Retrieved from: https://plus.maths.org/content/normal-distribution
